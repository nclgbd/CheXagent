# %%
from model_chexagent.chexagent import CheXagent
import time
RUN_COUNT = 5

chexagent = CheXagent()
# Out:
# /home/rsamf/code/CheXagent/.venv/lib/python3.10/site-packages/huggingface_hub/file_download.py:945: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# /home/rsamf/code/CheXagent/.venv/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:2409: UserWarning: for logit_scale: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   warnings.warn(
# ...

# %% [markdown]
# ### View Classification

# %%
path = "https://prod-images-static.radiopaedia.org/images/23511538/8a28003cc78f3549ac9f436dfe7dad_big_gallery.jpeg"
count = 0.
for i in range(RUN_COUNT):
    start_time = time.perf_counter()
    response = chexagent.view_classification(path)
    count += time.perf_counter() - start_time
    print(response)
print(count / RUN_COUNT)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# (a) PA
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# (a) PA
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# ...

# %% [markdown]
# ### View Matching

# %%
path_1 = "https://prod-images-static.radiopaedia.org/images/17054297/07b3ca19d485b21a30bd8412dbbc33_big_gallery.jpeg"
path_2 = "https://prod-images-static.radiopaedia.org/images/17054298/c42c7d29bfe0203554649e38e9be6c_big_gallery.jpeg"
count = 0.
for i in range(RUN_COUNT):
    start_time = time.perf_counter()
    response = chexagent.view_matching([path_1, path_2])
    count += time.perf_counter() - start_time
    print(response)
print(count / RUN_COUNT)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Yes
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Yes
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# ...

# %% [markdown]
# # Binary Disease Classification

# %%
image = "https://prod-images-static.radiopaedia.org/images/23511538/8a28003cc78f3549ac9f436dfe7dad_big_gallery.jpeg"
positive_class = "Pneumonia"
for i in range(RUN_COUNT):
    start_time = time.perf_counter()
    response = chexagent.binary_disease_classification([image], positive_class).lower()
    count += time.perf_counter() - start_time
    print(response)
print(count / RUN_COUNT)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# no
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# no
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# ...

# %%
path = "https://prod-images-static.radiopaedia.org/images/23511538/8a28003cc78f3549ac9f436dfe7dad_big_gallery.jpeg"
count = 0.
for i in range(RUN_COUNT):
    start_time = time.perf_counter()
    response = chexagent.disease_identification([path], ["Pneumothorax", "Pleural Effusion", "Pneumonia"])
    count += time.perf_counter() - start_time
    print(response)
print(count / RUN_COUNT)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Pneumothorax
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Pneumothorax
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# ...

# %%
path = "https://prod-images-static.radiopaedia.org/images/23511538/8a28003cc78f3549ac9f436dfe7dad_big_gallery.jpeg"
indication = "Shortness of breath and mild left sided pleuritic chest pain. No trauma."
count = 0.
for i in range(RUN_COUNT):
    start_time = time.perf_counter()
    response = chexagent.findings_generation([path], indication)
    count += time.perf_counter() - start_time
    print(response)
print(count / RUN_COUNT)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [Breathing: Pleura] **A small left apical pneumothorax is present.** [Breathing: Lungs] The lungs are otherwise clear. [Cardiac: Heart Size] The heart size is normal. [Everything else: Mediastinal] The mediastinal contours are normal. [Airway: Hilar Structures] The hilar contours are normal. [Breathing: Pleura] There are no pleural effusions.
# ...

# %%
path = "https://prod-images-static.radiopaedia.org/images/23511538/8a28003cc78f3549ac9f436dfe7dad_big_gallery.jpeg"
count = 0.
for i in range(RUN_COUNT):
    start_time = time.perf_counter()
    responses = chexagent.findings_generation_section_by_section([path])
    count += time.perf_counter() - start_time
    for response in responses:
        print(f'{response[0]}: {response[1]}')
print(count / RUN_COUNT)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# ...

# %%
path = "https://prod-images-static.radiopaedia.org/images/23511538/8a28003cc78f3549ac9f436dfe7dad_big_gallery.jpeg"
text = "No pneumothorax."
count = 0.
for i in range(RUN_COUNT):
    start_time = time.perf_counter()
    response = chexagent.image_text_matching([path], text)
    count += time.perf_counter() - start_time
    print(response)
print(count / RUN_COUNT)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Not matched
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Not matched
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# ...

# %%
path = "https://prod-images-static.radiopaedia.org/images/23511538/8a28003cc78f3549ac9f436dfe7dad_big_gallery.jpeg"
phrase = "There is a left apical pneumothorax."
count = 0.
for i in range(RUN_COUNT):
    start_time = time.perf_counter()
    response = chexagent.phrase_grounding(path, phrase)
    count += time.perf_counter() - start_time
    print(response)
print(count / RUN_COUNT)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Saving the result at results_visualization/phrase_grounding.png
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# <|ref|> There is a left apical pneumothorax <|/ref|> <|box|> (55,4),(86,24) <|/box|>
# Saving the result at results_visualization/phrase_grounding.png
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...

# %%
path = "https://prod-images-static.radiopaedia.org/images/23511538/8a28003cc78f3549ac9f436dfe7dad_big_gallery.jpeg"
disease_name = "Pneumothorax"
count = 0.
for i in range(RUN_COUNT):
    start_time = time.perf_counter()
    response = chexagent.abnormality_detection(path, disease_name)
    count += time.perf_counter() - start_time
    print(response)
print(count / RUN_COUNT)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Saving the result at results_visualization/abnormality_detection.png
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# <|ref|> Pneumothorax <|/ref|> <|box|> (54,4),(84,31) <|/box|>
# Saving the result at results_visualization/abnormality_detection.png
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...

# %%
path = "https://medschool.co/images/detail/cxr/chest-drain.jpg"
count = 0.
for i in range(RUN_COUNT):
    start_time = time.perf_counter()
    response = chexagent.chest_tube_detection(path)
    count += time.perf_counter() - start_time
    print(response)
print(count / RUN_COUNT)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Saving the result at results_visualization/chest_tube_detection.png
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# <|ref|> chest tube <|/ref|> <|box|> (5,47),(44,91) <|/box|>
# Saving the result at results_visualization/chest_tube_detection.png
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...

# %%
path = "https://prod-images-static.radiopaedia.org/images/8719062/16f627c16c8b34bccd8857b95a259f_big_gallery.jpg"
count = 0.
for i in range(RUN_COUNT):
    start_time = time.perf_counter()
    response = chexagent.rib_fracture_detection(path)
    count += time.perf_counter() - start_time
    print(response)
print(count / RUN_COUNT)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Saving the result at results_visualization/rib_fracture_detection.png
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# <|ref|> rib fracture <|/ref|> <|box|> (8,70),(14,75) <|/box|> <|ref|> rib fracture <|/ref|> <|box|> (10,65),(16,69) <|/box|>
# Saving the result at results_visualization/rib_fracture_detection.png
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# ...

# %%
path = "https://images.squarespace-cdn.com/content/v1/56e8a86a746fb97ea9d14740/1517332911100-IZP0K9MTNA6M9Z1LHFF3/FB+CXR.png?format=2500w"
count = 0.
for i in range(RUN_COUNT):
    start_time = time.perf_counter()
    response = chexagent.foreign_objects_detection(path)
    count += time.perf_counter() - start_time
    print(response)
print(count / RUN_COUNT)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Saving the result at results_visualization/foreign_objects_detection.png
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# <|ref|> foreign object <|/ref|> <|box|> (46,34),(54,48) <|/box|>
# Saving the result at results_visualization/foreign_objects_detection.png
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...

# %%
prior_image_path = "https://prod-images-static.radiopaedia.org/images/58478828/0._big_gallery.jpeg"
current_image_path = "https://prod-images-static.radiopaedia.org/images/58478832/0._big_gallery.jpeg"
count = 0.
for i in range(RUN_COUNT):
    start_time = time.perf_counter()
    response = chexagent.temporal_image_classification([prior_image_path, current_image_path], "Pneumothorax")
    count += time.perf_counter() - start_time
    print(response)
print(count / RUN_COUNT)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# (c) improving
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# (c) improving
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# ...

# %%
findings = ("The endotracheal tube tip sits 5 cm above the carina. "
                "A left-sided IJ central venous catheter tip sits in the left brachiocephalic vein. "
                "The right-sided IJ central venous catheter tip sits in the upper SVC. "
                "The heart size is large but stable. The mediastinal contours are within normal limits. "
                "There continue to be bibasilar and perihilar opacities as well as a more rounded confluent opacity in "
                "the right upper lung. These findings likely represent increased pulmonary edema as well as right "
                "upper and lower lobe consolidations. Retrocardiac opacity is also compatible with a left lower lobe "
                "consolidation. The costophrenic angles are excluded from the study limiting assessment for subtle "
                "pleural effusion. There is no large pneumothorax.")
count = 0.
for i in range(RUN_COUNT):
    start_time = time.perf_counter()
    response = chexagent.findings_summarization(findings)
    count += time.perf_counter() - start_time
    print(response)
print(count / RUN_COUNT)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 1. Increased pulmonary edema with increased bibasilar and right upper lobe opacities. 2. Left lower lobe consolidation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...

# %%
text = "Right lower lobe opacity, concerning for infection."
count = 0.
for i in range(RUN_COUNT):
    start_time = time.perf_counter()
    response = chexagent.named_entity_recognition(text)
    count += time.perf_counter() - start_time
    print(response)
print(count / RUN_COUNT)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [Anatomy, Right], [Anatomy, lower], [Anatomy, lobe], [Observation (Definitely Present), opacity], [Observation (Definitely Present), infection]
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...
